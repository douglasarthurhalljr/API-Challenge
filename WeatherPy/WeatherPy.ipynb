# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint 
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

#Define empty lists to store values
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

#Looping through cities to make api calls using city as query
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
#Extracting data. Missing data is handled by try and except  
    try:
        
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
    except (KeyError):
        print("City not found. skipping.")
# Out:
# Processing record 1|paamiut
# Processing record 2|yulara
# Processing record 3|nanortalik
# Processing record 4|yellowknife
# City not found. skipping.
# Processing record 5|georgetown
# Processing record 6|punta arenas
# Processing record 7|albany
# Processing record 8|grindavik
# Processing record 9|natchitoches
# Processing record 10|redlands
# Processing record 11|victoria point
# Processing record 12|busselton
# Processing record 13|port alfred
# Processing record 14|mataura
# Processing record 15|nikolskoye
# Processing record 16|rikitea
# Processing record 17|new norfolk
# Processing record 18|jamestown
# Processing record 19|morvi
# City not found. skipping.
# Processing record 20|te anau
# City not found. skipping.
# Processing record 21|srednekolymsk
# Processing record 22|porto novo
# Processing record 23|chokurdakh
# Processing record 24|kruisfontein
# Processing record 25|tuktoyaktuk
# Processing record 26|shingu
# Processing record 27|richards bay
# Processing record 28|vila franca do campo
# Processing record 29|batagay
# Processing record 30|mahebourg
# Processing record 31|prince rupert
# Processing record 32|bambous virieux
# Processing record 33|esperance
# Processing record 34|klaksvik
# Processing record 35|san patricio
# Processing record 36|jalu
# Processing record 37|namatanai
# Processing record 38|tasiilaq
# Processing record 39|padang
# Processing record 40|adrar
# Processing record 41|vaini
# Processing record 42|florida ridge
# Processing record 43|yakeshi
# Processing record 44|taoudenni
# City not found. skipping.
# Processing record 45|tall kayf
# City not found. skipping.
# Processing record 46|umarga
# City not found. skipping.
# Processing record 47|tabou
# Processing record 48|saint-francois
# Processing record 49|cape town
# Processing record 50|cherskiy
# Processing record 51|torbay
# Processing record 52|sao filipe
# Processing record 53|nabire
# Processing record 54|taltal
# City not found. skipping.
# Processing record 55|luganville
# Processing record 56|victoria
# Processing record 57|east london
# Processing record 58|awbari
# Processing record 59|dikson
# Processing record 60|tura
# Processing record 61|salalah
# Processing record 62|perpignan
# Processing record 63|otane
# Processing record 64|belaya gora
# Processing record 65|hilo
# Processing record 66|puerto baquerizo moreno
# Processing record 67|bubaque
# Processing record 68|kodiak
# Processing record 69|sitka
# City not found. skipping.
# Processing record 70|saskylakh
# Processing record 71|sinegorye
# Processing record 72|quzhou
# Processing record 73|bluff
# Processing record 74|umba
# Processing record 75|wanlaweyn
# Processing record 76|ushuaia
# Processing record 77|motihari
# Processing record 78|bethel
# City not found. skipping.
# Processing record 79|airai
# Processing record 80|yenagoa
# Processing record 81|ribeira grande
# Processing record 82|meadow lake
# City not found. skipping.
# Processing record 83|san pedro
# Processing record 84|hobart
# Processing record 85|la ronge
# Processing record 86|pascagoula
# Processing record 87|luderitz
# Processing record 88|aklavik
# Processing record 89|talnakh
# Processing record 90|manono
# Processing record 91|boende
# Processing record 92|dingle
# Processing record 93|san vicente
# Processing record 94|champerico
# City not found. skipping.
# Processing record 95|bredasdorp
# Processing record 96|alihe
# Processing record 97|qaanaaq
# Processing record 98|kaitangata
# City not found. skipping.
# Processing record 99|shubarkuduk
# Processing record 100|chateauroux
# Processing record 101|hit
# Processing record 102|hofn
# Processing record 103|khatanga
# Processing record 104|the valley
# Processing record 105|saint-philippe
# Processing record 106|makakilo city
# Processing record 107|anchorage
# Processing record 108|port elizabeth
# Processing record 109|ponta delgada
# Processing record 110|pedernales
# Processing record 111|kapaa
# Processing record 112|fortuna
# Processing record 113|chuy
# Processing record 114|atuona
# Processing record 115|comodoro rivadavia
# Processing record 116|pisco
# Processing record 117|vilhena
# Processing record 118|ilo
# Processing record 119|hokitika
# Processing record 120|yaan
# City not found. skipping.
# Processing record 121|iqaluit
# Processing record 122|upernavik
# Processing record 123|thompson
# Processing record 124|arvika
# Processing record 125|barberton
# Processing record 126|krasnoselkup
# Processing record 127|guerrero negro
# Processing record 128|avarua
# Processing record 129|saint george
# Processing record 130|vorsma
# Processing record 131|norman wells
# Processing record 132|port-gentil
# Processing record 133|severo-kurilsk
# Processing record 134|fukue
# Processing record 135|provideniya
# Processing record 136|harper
# Processing record 137|monrovia
# Processing record 138|macas
# Processing record 139|korla
# Processing record 140|hithadhoo
# Processing record 141|kurchum
# Processing record 142|mogwase
# Processing record 143|carnarvon
# Processing record 144|hermanus
# Processing record 145|coihaique
# Processing record 146|cabo san lucas
# Processing record 147|veinticinco de mayo
# Processing record 148|steamboat springs
# Processing record 149|sisimiut
# Processing record 150|gari
# Processing record 151|barrow
# Processing record 152|mogadishu
# Processing record 153|mbini
# Processing record 154|muyezerskiy
# Processing record 155|cidreira
# Processing record 156|arlit
# Processing record 157|saint-joseph
# Processing record 158|kununurra
# Processing record 159|kavieng
# Processing record 160|yarada
# Processing record 161|bandarbeyla
# City not found. skipping.
# Processing record 162|bengkulu
# Processing record 163|karratha
# Processing record 164|puerto colombia
# City not found. skipping.
# Processing record 165|barcelos
# Processing record 166|moustheni
# Processing record 167|benguela
# Processing record 168|jerantut
# Processing record 169|liverpool
# Processing record 170|chapais
# Processing record 171|gimli
# Processing record 172|mayumba
# Processing record 173|camopi
# Processing record 174|broken hill
# Processing record 175|vostok
# Processing record 176|castro
# Processing record 177|kibre mengist
# City not found. skipping.
# Processing record 178|mercedes
# Processing record 179|sorong
# City not found. skipping.
# Processing record 180|ahipara
# Processing record 181|kuytun
# Processing record 182|goderich
# Processing record 183|tuy hoa
# Processing record 184|lat yao
# Processing record 185|bastia
# Processing record 186|sumbe
# Processing record 187|fairbanks
# City not found. skipping.
# Processing record 188|carauari
# Processing record 189|tacub
# Processing record 190|hamilton
# Processing record 191|gat
# Processing record 192|kasongo
# Processing record 193|tessalit
# Processing record 194|baghdad
# Processing record 195|longyearbyen
# Processing record 196|nemuro
# Processing record 197|huarmey
# Processing record 198|shar
# City not found. skipping.
# Processing record 199|santa cruz
# Processing record 200|mar del plata
# City not found. skipping.
# Processing record 201|san lorenzo
# Processing record 202|ternate
# Processing record 203|veraval
# Processing record 204|saint anthony
# Processing record 205|vestmanna
# City not found. skipping.
# Processing record 206|byron bay
# Processing record 207|alibag
# City not found. skipping.
# City not found. skipping.
# Processing record 208|bathsheba
# Processing record 209|tiznit
# Processing record 210|negara
# Processing record 211|trinidad
# Processing record 212|roebourne
# Processing record 213|sao joao da barra
# Processing record 214|antalaha
# Processing record 215|shurugwi
# Processing record 216|imbituba
# Processing record 217|vardo
# Processing record 218|puerto ayora
# Processing record 219|evensk
# Processing record 220|los llanos de aridane
# Processing record 221|booue
# Processing record 222|gamba
# Processing record 223|ponnani
# Processing record 224|dubrovytsya
# Processing record 225|ulverstone
# Processing record 226|faanui
# Processing record 227|shaunavon
# Processing record 228|maniitsoq
# Processing record 229|port hawkesbury
# Processing record 230|axim
# City not found. skipping.
# Processing record 231|zhanaozen
# Processing record 232|pokaran
# Processing record 233|zelenets
# Processing record 234|kieta
# Processing record 235|sainte-thecle
# Processing record 236|harrison
# Processing record 237|mamlyutka
# Processing record 238|altayskoye
# Processing record 239|george
# Processing record 240|bengbu
# Processing record 241|san cristobal
# Processing record 242|quatre cocos
# Processing record 243|xai-xai
# City not found. skipping.
# Processing record 244|saldanha
# Processing record 245|porto velho
# Processing record 246|sorland
# Processing record 247|camacha
# Processing record 248|tullow
# Processing record 249|tukrah
# Processing record 250|mount gambier
# Processing record 251|bonthe
# Processing record 252|cayenne
# Processing record 253|belmonte
# Processing record 254|cap malheureux
# City not found. skipping.
# City not found. skipping.
# Processing record 255|lagoa
# Processing record 256|husavik
# Processing record 257|ucluelet
# Processing record 258|abhar
# Processing record 259|ostrovnoy
# Processing record 260|tenenkou
# Processing record 261|kostomuksha
# Processing record 262|pitimbu
# Processing record 263|berdigestyakh
# Processing record 264|tahta
# City not found. skipping.
# Processing record 265|sharjah
# Processing record 266|maragogi
# Processing record 267|souillac
# Processing record 268|la concordia
# Processing record 269|tepoztlan
# City not found. skipping.
# Processing record 270|tiksi
# Processing record 271|haines junction
# Processing record 272|yar-sale
# Processing record 273|yerbogachen
# Processing record 274|bangkal
# Processing record 275|turayf
# Processing record 276|vredefort
# Processing record 277|kalmunai
# Processing record 278|waipawa
# Processing record 279|samarai
# Processing record 280|leningradskiy
# City not found. skipping.
# Processing record 281|rock sound
# Processing record 282|port moresby
# Processing record 283|zakamensk
# Processing record 284|buala
# Processing record 285|lupiro
# Processing record 286|dudinka
# Processing record 287|deputatskiy
# Processing record 288|babynino
# City not found. skipping.
# Processing record 289|pemangkat
# Processing record 290|ahar
# Processing record 291|boueni
# Processing record 292|banda aceh
# Processing record 293|sao geraldo do araguaia
# Processing record 294|kaeo
# Processing record 295|mehamn
# Processing record 296|kahului
# Processing record 297|cozumel
# Processing record 298|hovd
# Processing record 299|constitucion
# Processing record 300|lewiston
# Processing record 301|clyde river
# Processing record 302|saint-pierre
# Processing record 303|libreville
# Processing record 304|darhan
# Processing record 305|okhotsk
# Processing record 306|sambava
# Processing record 307|lexington
# Processing record 308|luena
# Processing record 309|arraial do cabo
# Processing record 310|olinda
# Processing record 311|poum
# Processing record 312|aripuana
# Processing record 313|sept-iles
# Processing record 314|alofi
# Processing record 315|seydisehir
# Processing record 316|athabasca
# Processing record 317|tripoli
# Processing record 318|sao domingos
# Processing record 319|beisfjord
# City not found. skipping.
# Processing record 320|marulanda
# Processing record 321|mao
# Processing record 322|san quintin
# Processing record 323|nokaneng
# Processing record 324|chickasha
# Processing record 325|coquimbo
# Processing record 326|acapulco
# Processing record 327|san rafael
# Processing record 328|butaritari
# Processing record 329|sur
# Processing record 330|dali
# Processing record 331|kandrian
# Processing record 332|ponta do sol
# City not found. skipping.
# Processing record 333|horadiz
# Processing record 334|paciran
# Processing record 335|seymchan
# Processing record 336|sampit
# Processing record 337|bardiyah
# Processing record 338|kovur
# Processing record 339|panguipulli
# Processing record 340|tiarei
# Processing record 341|saint-augustin
# City not found. skipping.
# Processing record 342|viransehir
# Processing record 343|hami
# Processing record 344|hasaki
# Processing record 345|ombessa
# Processing record 346|bulungu
# City not found. skipping.
# Processing record 347|jaru
# Processing record 348|pevek
# Processing record 349|poronaysk
# Processing record 350|challans
# Processing record 351|narsaq
# Processing record 352|gainesville
# Processing record 353|piacabucu
# Processing record 354|mangan
# Processing record 355|brattvag
# Processing record 356|codrington
# Processing record 357|verkhnevilyuysk
# Processing record 358|sulangan
# Processing record 359|aksarka
# Processing record 360|linjiang
# Processing record 361|trapani
# Processing record 362|iquitos
# Processing record 363|montrose
# Processing record 364|umm lajj
# City not found. skipping.
# Processing record 365|kutum
# Processing record 366|aktash
# Processing record 367|marawi
# Processing record 368|mareeba
# Processing record 369|aden
# Processing record 370|pangody
# Processing record 371|vihari
# Processing record 372|palmer
# Processing record 373|lebu
# Processing record 374|zilair
# Processing record 375|kavaratti
# Processing record 376|manaure
# Processing record 377|pangai
# Processing record 378|san andres
# Processing record 379|port macquarie
# Processing record 380|dolinsk
# Processing record 381|moose factory
# Processing record 382|seoul
# Processing record 383|mananjary
# Processing record 384|beringovskiy
# Processing record 385|oussouye
# Processing record 386|serebryanyy bor
# Processing record 387|yei
# Processing record 388|maceio
# City not found. skipping.
# Processing record 389|fare
# Processing record 390|penzance
# Processing record 391|labuhan
# Processing record 392|tuatapere
# Processing record 393|anadyr
# Processing record 394|nioro
# Processing record 395|mulanje
# Processing record 396|olafsvik
# Processing record 397|ayan
# Processing record 398|erenhot
# Processing record 399|katsuura
# City not found. skipping.
# City not found. skipping.
# Processing record 400|dickinson
# Processing record 401|minusinsk
# Processing record 402|nome
# Processing record 403|gao
# Processing record 404|vao
# Processing record 405|barmer
# Processing record 406|bambanglipuro
# Processing record 407|teapa
# Processing record 408|iranshahr
# Processing record 409|pangnirtung
# Processing record 410|denpasar
# Processing record 411|yeppoon
# Processing record 412|lavrentiya
# Processing record 413|kirakira
# Processing record 414|nishihara
# Processing record 415|rawson
# Processing record 416|viseu
# Processing record 417|salinas
# Processing record 418|hosdurga
# Processing record 419|haradok
# Processing record 420|oranjemund
# Processing record 421|okha
# Processing record 422|mbala
# City not found. skipping.
# Processing record 423|harwich
# Processing record 424|lensk
# Processing record 425|bonoua
# Processing record 426|araouane
# Processing record 427|bolong
# Processing record 428|vrangel
# Processing record 429|coari
# Processing record 430|general nakar
# Processing record 431|zharkent
# Processing record 432|namibe
# Processing record 433|ballitoville
# Processing record 434|coahuayana
# Processing record 435|palana
# Processing record 436|cabedelo
# Processing record 437|plaster rock
# Processing record 438|namtsy
# Processing record 439|ambilobe
# Processing record 440|egvekinot
# Processing record 441|maryville
# Processing record 442|kawardha
# Processing record 443|concarneau
# Processing record 444|faya
# Processing record 445|cockburn town
# Processing record 446|tougan
# Processing record 447|areia branca
# City not found. skipping.
# Processing record 448|pochutla
# Processing record 449|yajalon
# Processing record 450|lata
# Processing record 451|naze
# City not found. skipping.
# Processing record 452|bilma
# Processing record 453|shenxian
# Processing record 454|lima
# Processing record 455|lorengau
# Processing record 456|falavarjan
# Processing record 457|ola
# City not found. skipping.
# City not found. skipping.
# Processing record 458|port blair
# Processing record 459|gravdal
# Processing record 460|soe
# Processing record 461|bobo dioulasso
# Processing record 462|minden
# Processing record 463|ziniare
# Processing record 464|ilulissat
# Processing record 465|jerome
# Processing record 466|nazarovo
# Processing record 467|vila velha
# Processing record 468|curup
# Processing record 469|sonoita
# City not found. skipping.
# Processing record 470|hachinohe
# Processing record 471|santa maria
# Processing record 472|port maria
# Processing record 473|point pedro
# Processing record 474|margate
# Processing record 475|freeport
# Processing record 476|kalangala
# Processing record 477|concepcion del oro
# Processing record 478|lambarene
# Processing record 479|sabha
# Processing record 480|mizdah
# Processing record 481|tianpeng
# City not found. skipping.
# City not found. skipping.
# Processing record 482|honningsvag
# Processing record 483|roanoke rapids
# Processing record 484|santa luzia
# Processing record 485|palu
# Processing record 486|santa catalina
# Processing record 487|mocuba
# Processing record 488|muros
# Processing record 489|iskateley
# Processing record 490|gorontalo
# Processing record 491|qaqortoq
# Processing record 492|huilong
# Processing record 493|chitipa
# Processing record 494|brejo santo
# Processing record 495|fredericton
# Processing record 496|marquette
# City not found. skipping.
# Processing record 497|pasighat
# Processing record 498|bombay
# Processing record 499|jiwani
# Processing record 500|tatawin
# Processing record 501|villarrobledo
# Processing record 502|isangel
# Processing record 503|shengjin
# Processing record 504|la rioja
# Processing record 505|itarema
# Processing record 506|dodge city
# Processing record 507|chernyshevskiy
# City not found. skipping.
# Processing record 508|quesnel
# Processing record 509|hay river
# Processing record 510|bergerac
# City not found. skipping.
# Processing record 511|charters towers
# Processing record 512|hammerfest
# Processing record 513|sibu
# Processing record 514|jackson
# Processing record 515|senneterre
# Processing record 516|siavonga
# Processing record 517|severomuysk
# Processing record 518|christchurch
# Processing record 519|bacolod
# Processing record 520|emirdag
# Processing record 521|shangzhi
# Processing record 522|tecolutla
# Processing record 523|morondava
# Processing record 524|devonport
# Processing record 525|glenwood springs
# Processing record 526|san carlos de bariloche
# Processing record 527|mabaruma
# Processing record 528|innisfail
# Processing record 529|kristiinankaupunki
# Processing record 530|gigmoto
# Processing record 531|maraa
# Processing record 532|prieska
# Processing record 533|skelleftea
# Processing record 534|nuuk
# Processing record 535|vientiane
# Processing record 536|flin flon
# Processing record 537|klang
# Processing record 538|college
# Processing record 539|lakes entrance
# Processing record 540|karasjok
# Processing record 541|bilibino
# Processing record 542|linfen
# Processing record 543|walvis bay
# Processing record 544|marsabit
# Processing record 545|viedma
# Processing record 546|lumberton
# City not found. skipping.
# Processing record 547|san ignacio
# Processing record 548|srandakan
# Processing record 549|westport
# Processing record 550|ilhabela
# Processing record 551|north vanlaiphai
# City not found. skipping.
# Processing record 552|mineral wells
# Processing record 553|mitu
# Processing record 554|aswan
# Processing record 555|borogontsy
# Processing record 556|tautira
# City not found. skipping.
# Processing record 557|lakselv
# Processing record 558|port lincoln
# Processing record 559|kysyl-syr
# City not found. skipping.
# Processing record 560|pacific grove
# Processing record 561|hambantota
# Processing record 562|lompoc
# City not found. skipping.
# Processing record 563|komsomolskiy
# Processing record 564|letterkenny
# Processing record 565|caravelas
# Processing record 566|surt
# Processing record 567|shimoda

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating city dataframe
city_df = pd.DataFrame({"City":city_name,
                       "Cloudiness":cloudiness,
                       "Country":country,
                       "Date":date,
                       "Humidity":humidity,
                       "Lat":lat,
                       "Lng":lng,
                       "Max Temp":max_temp,
                       "Wind Speed":wind_speed})

city_df = city_df.rename_axis('City ID')

#Exporting data to Csv
city_df.to_csv("../output_data/cities.csv")

#Display dataframe
city_df.head()
# Out:
#                 City  Cloudiness Country        Date  Humidity      Lat  \
# City ID
# 0            Paamiut          22      GL  1615586778        73  61.9940
# 1             Yulara          90      AU  1615586779        78 -25.2406
# 2         Nanortalik           1      GL  1615586779        70  60.1432
# 3        Yellowknife          75      CA  1615586708        56  62.4560
# 4        George Town          20      MY  1615586488        94   5.4112
#
#               Lng  Max Temp  Wind Speed
# City ID
# 0        -49.6678     13.08        6.85
# 1        130.9889     73.40        5.75
# 2        -45.2371     15.44        9.19
# 3       -114.3525      8.60       17.27
# 4        100.3354     77.00        2.30

# %%
city_df.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
timestamp = city_df["Date"][0]
converted_timestamp = datetime.utcfromtimestamp(timestamp)
shortened_timestamp = datetime.date(converted_timestamp)

#Creating plot
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature({shortened_timestamp})")
plt.savefig("../output_data/Lat_vs_temp_plot")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Lat"], city_df["Humidity"], marker = "o", color = "blue",edgecolor = "black")
plt.grid
plt.ylim(0, city_df["Humidity"].max()+50)
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title(f"City Latitude vs. Humidity({shortened_timestamp})")
plt.savefig("../output_data/Lat_vs_humidity_plot")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Lat"], city_df["Cloudiness"], marker = "o", color = "blue",edgecolor = "black")
plt.grid
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs. Cloudiness({shortened_timestamp})")
plt.savefig("../output_data/Lat_vs_cloudiness_plot")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Lat"], city_df["Wind Speed"], marker = "o", color = "blue",edgecolor = "black")
plt.grid
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.title(f"City Latitude vs. Wind Speed({shortened_timestamp})")
plt.savefig("../output_data/Lat_vs_Wind Speed_plot")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Create a function to create Linear Regression plots
# Add the linear regression equation and line to plot
def linear_reg_plot(x_values,y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
    plt.xlabel("Latitude")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hemisphere = city_df.loc[city_df["Lat"]>0]
Southern_hemisphere = city_df.loc[city_df["Lat"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern_hemisphere["Lat"]
y_values = Northern_hemisphere["Max Temp"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: -0.8921275579912847
# None

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_hemisphere["Lat"]
y_values = Southern_hemisphere["Max Temp"]
plt.ylabel("Max Temp (F)")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: 0.5212193724057429
# None

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_hemisphere["Lat"]
y_values = Northern_hemisphere["Humidity"]
plt.ylabel("Humidity(%)")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: 0.19534530863130004
# None

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_hemisphere["Lat"]
y_values = Southern_hemisphere["Humidity"]
plt.ylabel("Humidity(%)")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: 0.3781482752446223
# None

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_hemisphere["Lat"]
y_values = Northern_hemisphere["Cloudiness"]
plt.ylabel("Cloudiness")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: 0.19733142073643212
# None

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_hemisphere["Lat"]
y_values = Southern_hemisphere["Cloudiness"]
plt.ylabel("Cloudiness")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: 0.3060490307473557
# None

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_hemisphere["Lat"]
y_values = Northern_hemisphere["Wind Speed"]
plt.ylabel("Wind Speed")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: 0.20782856946758563
# None

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_hemisphere["Lat"]
y_values = Southern_hemisphere["Wind Speed"]
plt.ylabel("Wind Speed")
print(linear_reg_plot(x_values,y_values))
# Out:
# The r-squared is: -0.26979062131574216
# None
